# %%
import pandas as pd
import numpy as np

bekasi = pd.read_csv('https://raw.githubusercontent.com/Ammardaffala/ADM-Case-01-EDA/main/data/bekasi.csv')
bogor = pd.read_csv('https://raw.githubusercontent.com/Ammardaffala/ADM-Case-01-EDA/main/data/bogor.csv')
depok = pd.read_csv('https://raw.githubusercontent.com/Ammardaffala/ADM-Case-01-EDA/main/data/depok.csv')
jakarta = pd.read_csv('https://raw.githubusercontent.com/Ammardaffala/ADM-Case-01-EDA/main/data/jakarta.csv')
tanggerang = pd.read_csv('https://raw.githubusercontent.com/Ammardaffala/ADM-Case-01-EDA/main/data/tangerang.csv')

# %%
bekasi.info() , bogor.info(), depok.info(), jakarta.info(), tanggerang.info()
print('\n')
display(bekasi.head(),bogor.head(),depok.head(),jakarta.head(),tanggerang.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   created_at   107 non-null    object
#  1   LT           107 non-null    float64
#  2   LB           107 non-null    float64
#  3   KT           107 non-null    float64
#  4   KM           106 non-null    float64
#  5   garasi       33 non-null     float64
#  6   carport      81 non-null     float64
#  7   lokasi       107 non-null    object
#  8   sertifikat   106 non-null    object
#  9   listrik      101 non-null    float64
#  10  hadap        48 non-null     object
#  11  harga        107 non-null    float64
#  12  URL          107 non-null    object
#  13  deskripsi    107 non-null    object
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
### Drop Unnamed columns ###

bekasi.drop(columns=['hadap', 'created_at', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace = True)

bogor.drop(columns=['hadap','created_at', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace = True)

jakarta.drop(columns=['hadap','created_at', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace = True)

depok.drop(columns=['hadap','created_at', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace = True)

tanggerang.drop(columns=['hadap','created_at', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], inplace = True)

# %%
bekasi.columns, bogor.columns, jakarta.columns, depok.columns, tanggerang.columns
# Out:
# (Index(['LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi', 'sertifikat',
#         'listrik', 'harga', 'URL', 'deskripsi'],
#        dtype='object'),
#  Index(['LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi', 'sertifikat',
#         'listrik', 'harga', 'URL', 'deskripsi'],
#        dtype='object'),
#  Index(['LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi', 'sertifikat',
#         'listrik', 'harga', 'URL', 'deskripsi'],
#        dtype='object'),
#  Index(['LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi', 'sertifikat',
#         'listrik', 'harga', 'URL', 'deskripsi'],
#        dtype='object'),
#  Index(['LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi', 'sertifikat',
#         'listrik', 'harga', 'URL', 'deskripsi'],
#        dtype='object'))

# %%
display(bekasi.head(),bogor.head(),depok.head(),jakarta.head(),tanggerang.head())
# Out:
#       LT     LB   KT   KM  garasi  carport            lokasi sertifikat  \
# 0   71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 1   59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 2  124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 3  144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 4  108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi        SHM
#
#    listrik         harga                                                URL  \
# 0   1300.0  5.500000e+08  Rumah murah di metland cibitung bekasi - Dijua...
# 1      NaN  4.400000e+08  Rumah dijual di Griya gandasari cibitung - Dij...
# 2      NaN  6.990000e+08  Jual cepat rumah huuk di metland cibitung beka...
# 3   2200.0  1.350000e+09  https://www.realoka.com/216243-rumah-rapi-siap...
# 4   2200.0  1.400000e+09  https://www.realoka.com/207964-jual-rumah-bagu...
#
#                                            deskripsi
# ...

# %%
jakarta.dropna(how = 'all', inplace = True)
bogor.dropna(how = 'all', inplace = True)
depok.dropna(how = 'all', inplace = True)
tanggerang.dropna(how = 'all', inplace = True)
bekasi.dropna(how = 'all', inplace = True)

# %%
### Merging ###

frames = [jakarta, depok, bekasi, tanggerang, bogor]
df = pd.concat(frames, keys=["Jakarta", "Depok", "Bekasi", "Tanggerang", "Bogor"])
df
# Out:
#                 LT     LB   KT   KM  garasi  carport         lokasi  \
# Jakarta 0    202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
#         1     30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
#         2     19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
#         3     33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
#         4     30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ...            ...    ...  ...  ...     ...      ...            ...
# Bogor   188   90.0   36.0  2.0  1.0     0.0      1.0   Gunung Putri
#         189  107.0   31.0  2.0  1.0     0.0      1.0       Sukaraja
#         190  210.0  150.0  4.0  2.0     1.0      1.0  Bogor Selatan
#         191   90.0   36.0  2.0  1.0     0.0      1.0      Cileungsi
#         192   72.0   90.0  3.0  2.0     1.0      1.0       Cibinong
#
#             sertifikat  listrik         harga  \
# Jakarta 0          SHM   2200.0  4.500000e+09
#         1          SHM   2200.0  1.100000e+09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 665 entries, ('Jakarta', 0) to ('Bogor', 192)
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LT          665 non-null    object
#  1   LB          663 non-null    float64
#  2   KT          663 non-null    float64
#  3   KM          662 non-null    float64
#  4   garasi      333 non-null    float64
#  5   carport     550 non-null    float64
#  6   lokasi      663 non-null    object
#  7   sertifikat  658 non-null    object
#  8   listrik     628 non-null    float64
#  9   harga       663 non-null    float64
#  10  URL         663 non-null    object
#  11  deskripsi   654 non-null    object
# dtypes: float64(7), object(5)
# memory usage: 69.9+ KB

# %%
### Missing Values in Each Columns ###

df.isna().sum()
# Out:
# LT              0
# LB              2
# KT              2
# KM              3
# garasi        332
# carport       115
# lokasi          2
# sertifikat      7
# listrik        37
# harga           2
# URL             2
# deskripsi      11
# dtype: int64

# %%
## Exclude Missing Values Based on Conditions ##

df2 = df.dropna(subset=['harga', 'LT', 'LB', 'KT', 'KM'])

# %%
df2.isna().sum()
# Out:
# LT              0
# LB              0
# KT              0
# KM              0
# garasi        330
# carport       112
# lokasi          0
# sertifikat      4
# listrik        34
# harga           0
# URL             0
# deskripsi       9
# dtype: int64

# %%
### Check for Duplicates ###

print('Number of duplicates: ', df2.duplicated().sum())
df3 = df2.drop_duplicates
# Out:
# Number of duplicates:  0

# %%
df2['LT'] = pd.to_numeric(df2['LT'], errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Dari proses pengolahan data yang telah dilakukan, menurut kami, kualitas data yang saat ini dimiliki perusahaan masih belum dapat dikatakan baik karena terdapat banyak missing row, yaitu baris yang tidak memiliki data sama sekali tetapi terhitung menjadi entry pada data. Selain itu, data masih memiliki kolom-kolom yang tidak terdefinisi serta tidak memilki nilai isi. Kemudian, masih banyak missing value dan outlier, dimana missing value adalah data kosong yang dapat menganggu analisis, sedangkan outlier adalah data nilai ekstrim dibandingkan dengan nilai-nilai lainnya pada data.
#
# File data yang dimiliki perusahaan juga masih terpisah-pisah berdasarkan lokasi daerah, sehingga diperlukan proses menyatukan data.

# %% [markdown]
# Sehingga, saran yang dapat kami berikan terkait data adalah sebaiknya dibuat database untuk semua daerah yang ingin dianalisis. Hal ini dilakukan untuk mempermudah proses analisis.
#
# Selain itu, diperlukan proses analisis ulang oleh data engineer untuk memastikan data tidak terdapat missing value.

# %%
### Detecting Outliers in The Data ###

fig, axs = plt.subplots(1, 5)

sns.boxplot(data=jakarta, y='harga', ax=axs[0])
sns.boxplot(data=bekasi, y='harga', ax=axs[1])
sns.boxplot(data=tanggerang, y='harga', ax=axs[2])
sns.boxplot(data=depok, y='harga', ax=axs[3])
sns.boxplot(data=bogor, y='harga', ax=axs[4])

fig.set_size_inches(18, 10)
plt.show()

# %% [markdown]
# Terlihat bahwa daerah Bekasi memiliki mean harga yang lebih tinggi dibandingkan dengan ke-empat daerah lainnya. Dari boxplot juga terlihat bahwa variasi harga di Bekasi lebih beragam, sedangkan harga rumah di Tanggerang tidak bervariasi dan paling murah. Kemudian, daerah termurah dengan urutan kedua, ketiga, dan keempat berturut-turut adalah daerah Jakarta, Bogor, dan Depok.
#
# Berdasarkan informasi tersebut, maka kami menyarankan Perusahaan RPPI untuk membuka cabang di daerah Bekasi karena harga rumah yang tersedia bervariasi sehingga dapat menjangkau banyak kalangan dari berbagai level ekonomi masyarakat.

# %%
# Cek Statistik Deskriptif

df2.describe()
# Out:
#                 LT           LB          KT          KM      garasi  \
# count   662.000000   662.000000  662.000000  662.000000  332.000000
# mean    163.477341   150.862538    3.152568    2.303625    0.828313
# std     242.192785   199.137590    1.386989    1.374047    1.292804
# min      16.000000    15.000000    1.000000    1.000000    0.000000
# 25%      67.500000    50.000000    2.000000    1.000000    0.000000
# 50%      93.500000    82.500000    3.000000    2.000000    0.000000
# 75%     160.000000   179.500000    4.000000    3.000000    1.000000
# max    3422.000000  2500.000000   10.000000   10.000000   10.000000
#
#           carport       listrik         harga
# count  550.000000    628.000000  6.620000e+02
# mean     1.494545   3057.961783  2.188322e+09
# std      1.080953   4770.949803  7.602457e+09
# min      0.000000    900.000000  4.100000e+01
# 25%      1.000000   1300.000000  1.950000e+03
# 50%      1.000000   2200.000000  4.560000e+08
# ...

# %%
### Cek Modus ###

df2.mode()
# Out:
#      LT    LB   KT   KM  garasi  carport       lokasi sertifikat  listrik  \
# 0  60.0  36.0  2.0  2.0     0.0      1.0  Kota Bekasi        SHM   2200.0
# 1   NaN   NaN  NaN  NaN     NaN      NaN          NaN        NaN      NaN
# 2   NaN   NaN  NaN  NaN     NaN      NaN          NaN        NaN      NaN
#
#           harga                                                URL  \
# 0  1.700000e+03  https://www.rumah123.com/perumahan-baru/proper...
# 1  1.200000e+09                                                NaN
# 2  1.400000e+09                                                NaN
#
#                                            deskripsi
# 0  Dekat dengan berbagai fasilitas seperti :\nSek...
# 1                                                NaN
# 2                                                NaN

# %% [markdown]
# Dari informasi diatas, maka kriteria rumah yang paling banyak dijual adalah rumah dengan Kamar Mandi dan Kamar Tidur berjumlah 2 serta memiliki sertifikat SHM dan lahan untuk parkir kendaraan.
